# %% [markdown]
# # EMS741 - Coursework - few-shot learning for medical image segmentation
#
# Team: [Please enter team member details here]

# %% [markdown]
# The data for the coursework is available [here](https://zenodo.org/records/18745413), and can be downloaded as follows.

# %%
# !wget -O data.zip https://zenodo.org/records/18745413/files/ems741_cw_data.zip?download=1
# Out:
# --2026-03-02 09:39:53--  https://zenodo.org/records/18745413/files/ems741_cw_data.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.184.103.118, 137.138.52.235, 188.185.48.75, ...
# Connecting to zenodo.org (zenodo.org)|188.184.103.118|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 173581469 (166M) [application/octet-stream]
# Saving to: ‘data.zip’
#
# data.zip            100%[===================>] 165.54M   925KB/s    in 3m 12s
#
# 2026-03-02 09:43:06 (881 KB/s) - ‘data.zip’ saved [173581469/173581469]

# %%
import zipfile
import os

path_to_zip = r'data.zip'
path_to_extract_to = r'./'

with zipfile.ZipFile(path_to_zip, 'r') as zip_ref:
    zip_ref.extractall(path_to_extract_to)

# %%
# !ls ./train
# Out:
# task_2	task_3	task_5	task_7

# %%
# !ls ./val
# Out:
# task_4	task_6

# %%
# !ls ./test
# Out:
# task_1	task_8

# %% [markdown]
# ### Your approach
