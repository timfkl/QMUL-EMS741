# %%
# !sudo apt update
# !sudo apt install -y pciutils zstd
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://cli.github.com/packages stable/main amd64 Packages [357 B]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [85.2 kB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,388 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,807 kB]
# Get:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]m
# ...

# %%
import threading
import subprocess
import time

def run_ollama_serve():
  subprocess.Popen(["ollama", "serve"])

thread = threading.Thread(target=run_ollama_serve)
thread.start()
time.sleep(5)

# %%
# !pip install ollama

# %%
# !ollama pull llama3.2:1b

# %%
from ollama import chat

stream = chat(
    model='llama3.2:1b',
    messages=[{'role': 'user', 'content': 'what are the best landmarks in london'}],
    stream=True,
    options={"temperature": 0.0} # set between 0.0 to 2.0+
)

for chunk in stream:
  print(chunk['message']['content'], end='', flush=True)
# Out:
# London is a city with a rich history, diverse culture, and iconic landmarks that attract millions of visitors each year. Here are some of the best landmarks to visit in London:
#
# 1. Buckingham Palace: The official residence of the British monarch, Buckingham Palace is a must-visit attraction in London. Watch the Changing of the Guard ceremony, which takes place daily at 11:30 am from April to July and on alternate days the rest of the year.
# 2. The Tower of London: This historic fortress has served as a palace, prison, armory, and even a zoo over the centuries. Today, it's home to the Crown Jewels and the Yeoman Warders (also known as Beefeaters).
# 3. Big Ben and the Houses of Parliament: This iconic clock tower is a symbol of London and a popular spot for photos. Take a tour of the Houses of Parliament to learn about British politics and history.
# ...

# %% [markdown]
# ### Exploring the impact of temperature
#
# In this lab session, you will be exploring the impact of temperature on the answers produced by an LLM.
#
# First create a function that takes in a prompt and a temperature and prints out the LLM response.
#
# Then think of 3 prompts:
# 1) a factual problem (e.g., coding)
# 2) a mix of factual and creative (e.g., trip planning)
# 3) a creative problem (e.g., a short poem about something)
#
# Then test the LLM with at least 4 different temperature values (between 0.0 - 2.0) for each prompt.
#
# Then comment on what temperature setting is useful for each type of prompt and what impact it had.
#
# Then explore other things like:
# - what does 'role' do in the above code? what can you change this to and why would you change this?
# - are there any other options of the LLM that you can adjust?
# - can you use a different LLM and repeat this task?

# %%
def processResponse(prompt, temperature):
    stream = chat(
    model='llama3.2:1b',
    messages=prompt,
    stream=True,
    options={"temperature": temperature} # set between 0.0 to 2.0+
    )

    for chunk in stream:
        print(chunk['message']['content'], end= '', flush=True)

# %%
promptTest = [
    {
        'role': 'user', 
        'content': 'what are the best landmarks in london'
    },
    {
        'role': 'assistant',
        'content': 'What is 1+1'
    },
    {
        'role': 'user',
        'content': 'What is the capital of France?'
    }        
    ]
temptTest = 1.0
processResponse(promptTest, temptTest)
# Out:
# The capital of France is Paris.
