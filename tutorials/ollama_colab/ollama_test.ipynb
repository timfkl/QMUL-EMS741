# %%
# !mamba install -y -c conda-forge ollama

import subprocess
import time

print("Starting Ollama server from Conda environment...")
# Start the server in the background
server = subprocess.Popen(["ollama", "serve"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# Give it a few seconds to spin up
time.sleep(3)

print("Pulling model...")
# !ollama pull llama3
print("Ready!")
# Out:
# Looking for: ['ollama']
#
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━━  29.3kB /  53.5MB @ 514.9kB/s  0.1s
# conda-forge/noarch   ━━━╸━━━━━━━━━━━━━━━╸━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s[+] 0.2s
# conda-forge/linux-64 ━━━╸━━━━━━━━━━━━━━━━━━━  11.5MB /  53.5MB @  62.1MB/s  0.2s
# conda-forge/noarch   ━╸━━━━━━━━━━━━━━━━━━━━━   3.6MB /  26.2MB @  20.7MB/s  0.2s[+] 0.3s
# conda-forge/linux-64 ━━━━━╸━━━━━━━━━━━━━━━━━  16.4MB /  53.5MB @  64.5MB/s  0.3s
# conda-forge/noarch   ━━━━━━━╸━━━━━━━━━━━━━━━  10.4MB /  26.2MB @  35.2MB/s  0.3s[+] 0.4s
# conda-forge/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━  27.5MB /  53.5MB @  76.8MB/s  0.4s
# conda-forge/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━  10.8MB /  26.2MB @  27.1MB/s  0.4s[+] 0.5s
# conda-forge/linux-64 ━━━━━━━━━━━━━━╸━━━━━━━━  36.8MB /  53.5MB @  76.7MB/s  0.5s
# conda-forge/noarch   ━━━━━━━━━━╸━━━━━━━━━━━━  13.5MB /  26.2MB @  29.1MB/s  0.5s[+] 0.6s
# ...
