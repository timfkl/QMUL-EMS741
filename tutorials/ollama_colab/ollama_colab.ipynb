# %%
# !sudo apt update
# !sudo apt install -y pciutils zstd
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# sudo: The "no new privileges" flag is set, which prevents sudo from running as root.
# sudo: If sudo is running in a container, you may need to adjust the container configuration to disable the flag.
# sudo: The "no new privileges" flag is set, which prevents sudo from running as root.
# sudo: If sudo is running in a container, you may need to adjust the container configuration to disable the flag.
# >>> Installing ollama to /usr/local
# sudo: The "no new privileges" flag is set, which prevents sudo from running as root.
# sudo: If sudo is running in a container, you may need to adjust the container configuration to disable the flag.

# %%
import threading
import subprocess
import time

def run_ollama_serve():
  subprocess.Popen(["ollama", "serve"])

thread = threading.Thread(target=run_ollama_serve)
thread.start()
time.sleep(5)
# Out:
# Exception in thread Thread-4 (run_ollama_serve):
# Traceback (most recent call last):
#   File "/home/jovyan/env/mamba-gpu/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/home/jovyan/env/mamba-gpu/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "/home/jovyan/env/mamba-gpu/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_84797/2856519456.py", line 6, in run_ollama_serve
#   File "/home/jovyan/env/mamba-gpu/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/jovyan/env/mamba-gpu/lib/python3.11/subprocess.py", line 1950, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'ollama'

# %%
# !ollama run llama3.2:1b 'hello world'
# Out:
# /bin/bash: line 1: ollama: command not found

# %% [markdown]
# After running everything, click on 'Terminal' below. And in type:
#
# ```
# ollama run llama3.2:1b
# ```
#
# If you want to paste things into the terminal please use ctrl+shift+v.
#
# If you want to copy things (e.g., chat history) then please use right click and copy.
